# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import pylab as plt

# %%
#train_data = pd.read_csv('C:\Prajeen\Career Development\Innoweek\Data Collection\From Suraj\ML Data Collection_Suraj.csv')

train_Mess_Created = pd.read_csv('./Stages/when message is created.csv')
train_2_days_b4_BI = pd.read_csv('./Stages/2 days b4 BI is communicated.csv')
train_BI_communicated = pd.read_csv('./Stages/when BI is communicated.csv')
train_7_days_b4_Esc = pd.read_csv('./Stages/7 days before escalation.csv')
train_2_days_b4_Esc = pd.read_csv('./Stages/2 days before escalation.csv')
train_mess_Escalated = pd.read_csv('./Stages/When message escalated.csv')

# %%
# Set the global default size of matplotlib figures
plt.rc('figure', figsize=(10,5))
# Size of matplotlib figures that contain subplots
fizsize_with_subplots = (20, 3)

# %%
fig = plt.figure(figsize=fizsize_with_subplots)
fig_dims=(1,6)

plt.subplot2grid(fig_dims,(0,0))
train_Mess_Created['Priority'].value_counts().plot(kind='bar', title='Priority_Mess_Created')

plt.subplot2grid(fig_dims,(0,1))
train_2_days_b4_BI['Priority'].value_counts().plot(kind='bar', title='Priority_2_days_b4_B')

plt.subplot2grid(fig_dims,(0,2))
train_BI_communicated['Priority'].value_counts().plot(kind='bar', title='Priority_BI_communicated')

plt.subplot2grid(fig_dims,(0,3))
train_7_days_b4_Esc['Priority'].value_counts().plot(kind='bar', title='Priority_7_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,4))
train_2_days_b4_Esc['Priority'].value_counts().plot(kind='bar', title='Priority_2_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,5))
train_mess_Escalated['Priority'].value_counts().plot(kind='bar', title='Priority_mess_Escalated')

# %%
plt.rc('figure', figsize=(10,5))
fizsize_with_subplots = (20, 3)

fig = plt.figure(figsize=fizsize_with_subplots)
fig_dims=(1,6)

plt.subplot2grid(fig_dims,(0,0))
train_Mess_Created['APT'].value_counts().plot(kind='bar', title='APT_Mess_Created')

plt.subplot2grid(fig_dims,(0,1))
train_2_days_b4_BI['APT_New'].value_counts().plot(kind='bar', title='APT_2_days_b4_B')

plt.subplot2grid(fig_dims,(0,2))
train_BI_communicated['APT_New'].value_counts().plot(kind='bar', title='APT_BI_communicated')

plt.subplot2grid(fig_dims,(0,3))
train_7_days_b4_Esc['APT_New'].value_counts().plot(kind='bar', title='APT_7_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,4))
train_2_days_b4_Esc['APT_New'].value_counts().plot(kind='bar', title='APT_2_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,5))
train_mess_Escalated['APT_New'].value_counts().plot(kind='bar', title='APT_mess_Escalated')

# %%
plt.rc('figure', figsize=(10,5))
fizsize_with_subplots = (20, 3)

fig = plt.figure(figsize=fizsize_with_subplots)
fig_dims=(1,6)

plt.subplot2grid(fig_dims,(0,0))
train_Mess_Created['Calls from Customer'].value_counts().plot(kind='bar', title='Calls_Mess_Created')

plt.subplot2grid(fig_dims,(0,1))
train_2_days_b4_BI['Calls from Customer'].value_counts().plot(kind='bar', title='Calls_2_days_b4_B')

plt.subplot2grid(fig_dims,(0,2))
train_BI_communicated['Calls from Customer'].value_counts().plot(kind='bar', title='Calls_BI_communicated')

plt.subplot2grid(fig_dims,(0,3))
train_7_days_b4_Esc['Calls from Customer'].value_counts().plot(kind='bar', title='Calls_7_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,4))
train_2_days_b4_Esc['Calls from Customer'].value_counts().plot(kind='bar', title='Calls_2_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,5))
train_mess_Escalated['Calls from Customer'].value_counts().plot(kind='bar', title='Calls_mess_Escalated')

# %%
plt.rc('figure', figsize=(10,5))
fizsize_with_subplots = (20, 3)

fig = plt.figure(figsize=fizsize_with_subplots)
fig_dims=(1,6)

plt.subplot2grid(fig_dims,(0,0))
train_Mess_Created['TSLR'].value_counts().plot(kind='bar', title='TSLR_Mess_Created')

plt.subplot2grid(fig_dims,(0,1))
train_2_days_b4_BI['TSLR'].value_counts().plot(kind='bar', title='TSLR_2_days_b4_B')

plt.subplot2grid(fig_dims,(0,2))
train_BI_communicated['TSLR'].value_counts().plot(kind='bar', title='TSLR_BI_communicated')

plt.subplot2grid(fig_dims,(0,3))
train_7_days_b4_Esc['TSLR'].value_counts().plot(kind='bar', title='TSLR_7_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,4))
train_2_days_b4_Esc['TSLR'].value_counts().plot(kind='bar', title='TSLR_2_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,5))
train_mess_Escalated['TSLR'].value_counts().plot(kind='bar', title='TSLR_mess_Escalated')

# %%
plt.rc('figure', figsize=(10,5))
fizsize_with_subplots = (20, 3)

fig = plt.figure(figsize=fizsize_with_subplots)
fig_dims=(1,6)

plt.subplot2grid(fig_dims,(0,0))
train_Mess_Created['Number of Info to SAP from last TSLR'].value_counts().plot(kind='bar', title='Inf 2 SAP frm TSLR_Mess_Created')

plt.subplot2grid(fig_dims,(0,1))
train_2_days_b4_BI['Number of Info to SAP from last TSLR'].value_counts().plot(kind='bar', title='Inf 2 SAP frm TSLR_2_days_b4_B')

plt.subplot2grid(fig_dims,(0,2))
train_BI_communicated['Number of Info to SAP from last TSLR'].value_counts().plot(kind='bar', title='Inf 2 SAP frm TSLR_BI_communicated')

plt.subplot2grid(fig_dims,(0,3))
train_7_days_b4_Esc['Number of Info to SAP from last TSLR'].value_counts().plot(kind='bar', title='Inf 2 SAP frm TSLR_7_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,4))
train_2_days_b4_Esc['Number of Info to SAP from last TSLR'].value_counts().plot(kind='bar', title='Inf 2 SAP frm TSLR_2_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,5))
train_mess_Escalated['Number of Info to SAP from last TSLR'].value_counts().plot(kind='bar', title='Inf 2 SAP frm TSLR_mess_Escalated')

# %%
plt.rc('figure', figsize=(10,5))
fizsize_with_subplots = (20, 3)

fig = plt.figure(figsize=fizsize_with_subplots)
fig_dims=(1,6)

plt.subplot2grid(fig_dims,(0,0))
train_Mess_Created['Number of Processors'].value_counts().plot(kind='bar', title='Num f Pro_Mess_Created')

plt.subplot2grid(fig_dims,(0,1))
train_2_days_b4_BI['Number of Processors'].value_counts().plot(kind='bar', title='Num f Pro_2_days_b4_B')

plt.subplot2grid(fig_dims,(0,2))
train_BI_communicated['Number of Processors'].value_counts().plot(kind='bar', title='Num f Pro_BI_communicated')

plt.subplot2grid(fig_dims,(0,3))
train_7_days_b4_Esc['Number of Processors'].value_counts().plot(kind='bar', title='Num f Pro_7_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,4))
train_2_days_b4_Esc['Number of Processors'].value_counts().plot(kind='bar', title='Num f Pro_2_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,5))
train_mess_Escalated['Number of Processors'].value_counts().plot(kind='bar', title='Num f Pro_mess_Escalated')

# %%
plt.rc('figure', figsize=(10,5))
fizsize_with_subplots = (20, 3)

fig = plt.figure(figsize=fizsize_with_subplots)
fig_dims=(1,6)

plt.subplot2grid(fig_dims,(0,0))
train_Mess_Created['Customer call back request'].value_counts().plot(kind='bar', title='Callback R_Mess_Created')

plt.subplot2grid(fig_dims,(0,1))
train_2_days_b4_BI['Customer call back request'].value_counts().plot(kind='bar', title='Callback R_2_days_b4_B')

plt.subplot2grid(fig_dims,(0,2))
train_BI_communicated['Customer call back request'].value_counts().plot(kind='bar', title='Callback R_BI_communicated')

plt.subplot2grid(fig_dims,(0,3))
train_7_days_b4_Esc['Customer call back request'].value_counts().plot(kind='bar', title='Callback R_7_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,4))
train_2_days_b4_Esc['Customer call back request'].value_counts().plot(kind='bar', title='Callback R_2_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,5))
train_mess_Escalated['Customer call back request'].value_counts().plot(kind='bar', title='Callback R_mess_Escalated')

# %%
plt.rc('figure', figsize=(10,5))
fizsize_with_subplots = (20, 3)

fig = plt.figure(figsize=fizsize_with_subplots)
fig_dims=(1,6)

plt.subplot2grid(fig_dims,(0,0))
train_Mess_Created['Core Business affected?'].value_counts().plot(kind='bar', title='Core Business_Mess_Created')

plt.subplot2grid(fig_dims,(0,1))
train_2_days_b4_BI['Core Business affected?'].value_counts().plot(kind='bar', title='Core Business_2_days_b4_B')

plt.subplot2grid(fig_dims,(0,2))
train_BI_communicated['Core Business affected?'].value_counts().plot(kind='bar', title='Core Business_BI_communicated')

plt.subplot2grid(fig_dims,(0,3))
train_7_days_b4_Esc['Core Business affected?'].value_counts().plot(kind='bar', title='Core Business_7_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,4))
train_2_days_b4_Esc['Core Business affected?'].value_counts().plot(kind='bar', title='Core Business_2_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,5))
train_mess_Escalated['Core Business affected?'].value_counts().plot(kind='bar', title='Core Business_mess_Escalated')

# %%
plt.rc('figure', figsize=(10,5))
fizsize_with_subplots = (20, 3)

fig = plt.figure(figsize=fizsize_with_subplots)
fig_dims=(1,6)

plt.subplot2grid(fig_dims,(0,0))
train_Mess_Created['Go live Affected?'].value_counts().plot(kind='bar', title='Go live_Mess_Created')

plt.subplot2grid(fig_dims,(0,1))
train_2_days_b4_BI['Go live Affected?'].value_counts().plot(kind='bar', title='Go live_2_days_b4_B')

plt.subplot2grid(fig_dims,(0,2))
train_BI_communicated['Go live Affected?'].value_counts().plot(kind='bar', title='Go live_BI_communicated')

plt.subplot2grid(fig_dims,(0,3))
train_7_days_b4_Esc['Go live Affected?'].value_counts().plot(kind='bar', title='Go live_7_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,4))
train_2_days_b4_Esc['Go live Affected?'].value_counts().plot(kind='bar', title='Go live_2_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,5))
train_mess_Escalated['Go live Affected?'].value_counts().plot(kind='bar', title='Go live_mess_Escalated')

# %%
plt.rc('figure', figsize=(10,5))
fizsize_with_subplots = (20, 3)

fig = plt.figure(figsize=fizsize_with_subplots)
fig_dims=(1,6)

plt.subplot2grid(fig_dims,(0,0))
train_Mess_Created['Num of users affected'].value_counts().plot(kind='bar', title='Users_Mess_Created')

plt.subplot2grid(fig_dims,(0,1))
train_2_days_b4_BI['Num of users affected'].value_counts().plot(kind='bar', title='Users_2_days_b4_B')

plt.subplot2grid(fig_dims,(0,2))
train_BI_communicated['Num of users affected'].value_counts().plot(kind='bar', title='Users_BI_communicated')

plt.subplot2grid(fig_dims,(0,3))
train_7_days_b4_Esc['Num of users affected'].value_counts().plot(kind='bar', title='Users_7_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,4))
train_2_days_b4_Esc['Num of users affected'].value_counts().plot(kind='bar', title='Users_2_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,5))
train_mess_Escalated['Num of users affected'].value_counts().plot(kind='bar', title='Users_mess_Escalated')

# %%
plt.rc('figure', figsize=(10,5))
fizsize_with_subplots = (20, 3)

fig = plt.figure(figsize=fizsize_with_subplots)
fig_dims=(1,6)

plt.subplot2grid(fig_dims,(0,0))
train_Mess_Created['Work around available?'].value_counts().plot(kind='bar', title='Workaround_Mess_Created')

plt.subplot2grid(fig_dims,(0,1))
train_2_days_b4_BI['Work around available?'].value_counts().plot(kind='bar', title='Workaround_2_days_b4_B')

plt.subplot2grid(fig_dims,(0,2))
train_BI_communicated['Work around available?'].value_counts().plot(kind='bar', title='Workaround_BI_communicated')

plt.subplot2grid(fig_dims,(0,3))
train_7_days_b4_Esc['Work around available?'].value_counts().plot(kind='bar', title='Workaround_7_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,4))
train_2_days_b4_Esc['Work around available?'].value_counts().plot(kind='bar', title='Workaround_2_days_b4_Esc')

plt.subplot2grid(fig_dims,(0,5))
train_mess_Escalated['Work around available?'].value_counts().plot(kind='bar', title='Workaround_mess_Escalated')
